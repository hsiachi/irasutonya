# %%
import json
from PIL import Image
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
dir_path = '../data/data'
with open('../data/data/data_filtered.jsonl') as f:
    for line in f:
        a = json.loads(line)
        a['name']
        Image.open(f"{dir_path}/{a['images'][0]['path']}")
        break
# Out:
# 'ノーネクタイのイラスト（シャツ）'
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=184x450 at 0x7F2B6E502D90>
